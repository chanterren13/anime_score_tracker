# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import numpy as np

# %%
scores = pd.read_csv('scores/anime_scores.csv')
scores
# Out:
#                                                 name source  week  score
# 0                                          86 (2021)  anidb     2   7.45
# 1                                     Ousama Ranking  anidb     2   7.21
# 2    Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  anidb     2   7.19
# 3                                   Heike Monogatari  anidb     2   7.18
# 4                   Senpai ga Uzai Kouhai no Hanashi  anidb     2   7.12
# ..                                               ...    ...   ...    ...
# 195                         World Trigger 3rd Season    MAL    11   8.16
# 196                                      Blue Period    MAL    11   7.91
# 197                 Senpai ga Uzai Kouhai no Hanashi    MAL    11   7.87
# 198                                 Heike Monogatari    MAL    11   7.75
# 199                       Taishou Otome Otogibanashi    MAL    11   7.69
#
# [200 rows x 4 columns]

# %%
mal = scores[scores['source'] == 'MAL'].reset_index()
anidb = scores[scores['source'] == 'anidb'].reset_index()

# %%
mal = mal.pivot(index='week', columns='name', values='score')
mal
# Out:
# name  86 Part 2  Blue Period  Heike Monogatari  \
# week
# 2          8.62         7.82              7.70
# 3          8.61         7.78               NaN
# 4          8.63         7.76               NaN
# 5          8.64         7.75               NaN
# 6          8.65         7.75               NaN
# 7          8.63         7.75               NaN
# 8          8.62         7.75              7.76
# 9          8.60         7.75              7.75
# 10         8.58         7.88              7.75
# 11         8.55         7.91              7.75
#
# name  Kimetsu no Yaiba: Mugen Ressha-hen  Komi-san wa, Comyushou desu.  \
# week
# 2                                   8.59                          8.54
# 3                                   8.53                          8.50
# 4                                   8.48                          8.44
# 5                                   8.46                          8.40
# 6                                   8.43                          8.36
# 7                                   8.41                          8.34
# 8                                   8.37                          8.31
# 9                                   8.34                          8.29
# 10                                  8.34                          8.27
# 11                                  8.33                          8.24
#
# name  Mushoku Tensei: Isekai Ittara Honki Dasu Part 2  Ousama Ranking  \
# week
# 2                                                8.62            8.23
# 3                                                8.61            8.55
# 4                                                8.62            8.72
# 5                                                8.62            8.78
# 6                                                8.66            8.81
# 7                                                8.66            8.83
# 8                                                8.66            8.84
# 9                                                8.68            8.85
# 10                                               8.71            8.86
# 11                                               8.83            8.87
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei suru  \
# week
# 2                                                   NaN
# 3                                                  7.68
# 4                                                  7.70
# 5                                                  7.71
# 6                                                  7.71
# 7                                                  7.71
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
#
# name  Senpai ga Uzai Kouhai no Hanashi  Taishou Otome Otogibanashi  \
# week
# 2                                 7.77                         NaN
# 3                                 7.81                         NaN
# 4                                 7.84                         NaN
# 5                                 7.85                         NaN
# 6                                 7.86                         NaN
# 7                                 7.86                         NaN
# 8                                 7.86                         NaN
# 9                                 7.86                         NaN
# 10                                7.86                         NaN
# 11                                7.87                        7.69
#
# name  Takt Op. Destiny  World Trigger 3rd Season
# week
# 2                 8.15                      8.06
# 3                 8.10                      8.08
# 4                 8.00                      8.12
# 5                 7.93                      8.14
# 6                 7.86                      8.17
# 7                 7.81                      8.16
# 8                 7.78                      8.16
# 9                 7.76                      8.15
# 10                7.74                      8.15
# 11                 NaN                      8.16

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(mal.columns)))))
for col in list(mal.columns):
    c = next(color)
    plt.plot(mal[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#plt.ylim(7.5, 9.0)
plt.show()

# %%
anidb = anidb.pivot(index='week', columns='name', values='score')
anidb
# Out:
# name  86 (2021)  Blue Period  \
# week
# 2          7.45          NaN
# 3          7.63          NaN
# 4          7.71          NaN
# 5          7.57          NaN
# 6          7.59          NaN
# 7          7.66         6.84
# 8          7.72         6.85
# 9          7.77         6.90
# 10         7.76         7.06
# 11         7.67          NaN
#
# name  Gekijouban Sword Art Online: Progressive - Hoshinaki Yoru no Aria  \
# week
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                 7.12
# 11                                                 7.11
#
# name  Heike Monogatari  Isekai Shokudou 2  Kimetsu no Yaiba: Mugen Ressha Hen  \
# week
# 2                 7.18               6.81                                 NaN
# 3                 7.25                NaN                                7.19
# 4                 7.17                NaN                                7.33
# 5                 7.17                NaN                                7.29
# 6                 7.19               6.81                                7.40
# 7                 7.26                NaN                                7.48
# 8                 7.37                NaN                                7.50
# 9                 7.32                NaN                                7.58
# 10                7.34                NaN                                7.56
# 11                7.38                NaN                                7.59
#
# name  Kimetsu no Yaiba: Yuukaku Hen  Komi-san wa, Komyushou Desu.  \
# week
# 2                               NaN                          7.02
# 3                               NaN                          7.14
# 4                               NaN                          6.86
# 5                               NaN                          6.93
# 6                               NaN                          7.03
# 7                               NaN                          7.07
# 8                               NaN                          7.13
# 9                              7.84                          7.17
# 10                             7.57                          7.07
# 11                             7.51                          7.08
#
# name  Lupin Sansei: Part 6  Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  \
# week
# 2                     6.96                                             7.19
# 3                     7.13                                             7.33
# 4                     7.13                                             7.84
# 5                     7.20                                             7.78
# 6                     7.23                                             7.82
# 7                     7.23                                             7.87
# 8                     7.13                                             7.96
# 9                     7.13                                             8.00
# 10                     NaN                                             8.05
# 11                    6.98                                             8.25
#
# name  Ousama Ranking  Saihate no Paladin  \
# week
# 2               7.21                7.00
# 3               7.60                6.86
# 4               7.52                 NaN
# 5               7.52                 NaN
# 6               7.72                 NaN
# 7               7.72                 NaN
# 8               7.76                 NaN
# 9               7.81                 NaN
# 10              7.89                 NaN
# 11              7.95                 NaN
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei Suru  \
# week
# 2                                                  6.91
# 3                                                   NaN
# 4                                                  6.80
# 5                                                  6.73
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
#
# name  Senpai ga Uzai Kouhai no Hanashi  World Trigger 3rd Season
# week
# 2                                 7.12                       NaN
# 3                                 7.02                      7.10
# 4                                 7.00                      7.10
# 5                                 6.75                      7.08
# 6                                 6.79                      7.28
# 7                                 6.82                      7.28
# 8                                 6.93                      7.40
# 9                                  NaN                      7.52
# 10                                 NaN                      7.61
# 11                                 NaN                      7.66

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(anidb.columns)))))
for col in list(anidb.columns):
    c = next(color)
    plt.plot(anidb[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#plt.ylim(6.5, 8.0)
plt.show()
