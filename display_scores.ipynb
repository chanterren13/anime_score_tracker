# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import numpy as np

# %%
scores = pd.read_csv('scores/anime_scores.csv')
scores
# Out:
#                                                   name source  week  score
# 0                                            86 (2021)  anidb     2   7.45
# 1                                       Ousama Ranking  anidb     2   7.21
# 2      Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  anidb     2   7.19
# 3                                     Heike Monogatari  anidb     2   7.18
# 4                     Senpai ga Uzai Kouhai no Hanashi  anidb     2   7.12
# ..                                                 ...    ...   ...    ...
# 115                           World Trigger 3rd Season    MAL     7   8.16
# 116                   Senpai ga Uzai Kouhai no Hanashi    MAL     7   7.86
# 117                                   Takt Op. Destiny    MAL     7   7.81
# 118                                        Blue Period    MAL     7   7.75
# 119  Sekai Saikou no Ansatsusha, Isekai Kizoku ni T...    MAL     7   7.71
#
# [120 rows x 4 columns]

# %%
mal = scores[scores['source'] == 'MAL'].reset_index()
anidb = scores[scores['source'] == 'anidb'].reset_index()

# %%
mal = mal.pivot(index='week', columns='name', values='score')
mal
# Out:
# name  86 Part 2  Blue Period  Heike Monogatari  \
# week
# 2          8.62         7.82               7.7
# 3          8.61         7.78               NaN
# 4          8.63         7.76               NaN
# 5          8.64         7.75               NaN
# 6          8.65         7.75               NaN
# 7          8.63         7.75               NaN
#
# name  Kimetsu no Yaiba: Mugen Ressha-hen  Komi-san wa, Comyushou desu.  \
# week
# 2                                   8.59                          8.54
# 3                                   8.53                          8.50
# 4                                   8.48                          8.44
# 5                                   8.46                          8.40
# 6                                   8.43                          8.36
# 7                                   8.41                          8.34
#
# name  Mushoku Tensei: Isekai Ittara Honki Dasu Part 2  Ousama Ranking  \
# week
# 2                                                8.62            8.23
# 3                                                8.61            8.55
# 4                                                8.62            8.72
# 5                                                8.62            8.78
# 6                                                8.66            8.81
# 7                                                8.66            8.83
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei suru  \
# week
# 2                                                   NaN
# 3                                                  7.68
# 4                                                  7.70
# 5                                                  7.71
# 6                                                  7.71
# 7                                                  7.71
#
# name  Senpai ga Uzai Kouhai no Hanashi  Takt Op. Destiny  \
# week
# 2                                 7.77              8.15
# 3                                 7.81              8.10
# 4                                 7.84              8.00
# 5                                 7.85              7.93
# 6                                 7.86              7.86
# 7                                 7.86              7.81
#
# name  World Trigger 3rd Season
# week
# 2                         8.06
# 3                         8.08
# 4                         8.12
# 5                         8.14
# 6                         8.17
# 7                         8.16

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(mal.columns)))))
for col in list(mal.columns):
    c = next(color)
    plt.plot(mal[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#plt.ylim(7.5, 9.0)
plt.show()

# %%
anidb = anidb.pivot(index='week', columns='name', values='score')
anidb
# Out:
# name  86 (2021)  Blue Period  Heike Monogatari  Isekai Shokudou 2  \
# week
# 2          7.45          NaN              7.18               6.81
# 3          7.63          NaN              7.25                NaN
# 4          7.71          NaN              7.17                NaN
# 5          7.57          NaN              7.17                NaN
# 6          7.59          NaN              7.19               6.81
# 7          7.66         6.84              7.26                NaN
#
# name  Kimetsu no Yaiba: Mugen Ressha Hen  Komi-san wa, Komyushou Desu.  \
# week
# 2                                    NaN                          7.02
# 3                                   7.19                          7.14
# 4                                   7.33                          6.86
# 5                                   7.29                          6.93
# 6                                   7.40                          7.03
# 7                                   7.48                          7.07
#
# name  Lupin Sansei: Part 6  Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  \
# week
# 2                     6.96                                             7.19
# 3                     7.13                                             7.33
# 4                     7.13                                             7.84
# 5                     7.20                                             7.78
# 6                     7.23                                             7.82
# 7                     7.23                                             7.87
#
# name  Ousama Ranking  Saihate no Paladin  \
# week
# 2               7.21                7.00
# 3               7.60                6.86
# 4               7.52                 NaN
# 5               7.52                 NaN
# 6               7.72                 NaN
# 7               7.72                 NaN
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei Suru  \
# week
# 2                                                  6.91
# 3                                                   NaN
# 4                                                  6.80
# 5                                                  6.73
# 6                                                   NaN
# 7                                                   NaN
#
# name  Senpai ga Uzai Kouhai no Hanashi  World Trigger 3rd Season
# week
# 2                                 7.12                       NaN
# 3                                 7.02                      7.10
# 4                                 7.00                      7.10
# 5                                 6.75                      7.08
# 6                                 6.79                      7.28
# 7                                 6.82                      7.28

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(anidb.columns)))))
for col in list(anidb.columns):
    c = next(color)
    plt.plot(anidb[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylim(6.5, 8.0)
plt.show()
