# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import numpy as np

# %%
scores = pd.read_csv('scores/anime_scores.csv')
scores
# Out:
#                                                 name source  week  score
# 0                                          86 (2021)  anidb     2   7.45
# 1                                     Ousama Ranking  anidb     2   7.21
# 2    Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  anidb     2   7.19
# 3                                   Heike Monogatari  anidb     2   7.18
# 4                   Senpai ga Uzai Kouhai no Hanashi  anidb     2   7.12
# ..                                               ...    ...   ...    ...
# 155                         World Trigger 3rd Season    MAL     9   8.15
# 156                 Senpai ga Uzai Kouhai no Hanashi    MAL     9   7.86
# 157                                 Takt Op. Destiny    MAL     9   7.76
# 158                                 Heike Monogatari    MAL     9   7.75
# 159                                      Blue Period    MAL     9   7.75
#
# [160 rows x 4 columns]

# %%
mal = scores[scores['source'] == 'MAL'].reset_index()
anidb = scores[scores['source'] == 'anidb'].reset_index()

# %%
mal = mal.pivot(index='week', columns='name', values='score')
mal
# Out:
# name  86 Part 2  Blue Period  Heike Monogatari  \
# week
# 2          8.62         7.82              7.70
# 3          8.61         7.78               NaN
# 4          8.63         7.76               NaN
# 5          8.64         7.75               NaN
# 6          8.65         7.75               NaN
# 7          8.63         7.75               NaN
# 8          8.62         7.75              7.76
# 9          8.60         7.75              7.75
#
# name  Kimetsu no Yaiba: Mugen Ressha-hen  Komi-san wa, Comyushou desu.  \
# week
# 2                                   8.59                          8.54
# 3                                   8.53                          8.50
# 4                                   8.48                          8.44
# 5                                   8.46                          8.40
# 6                                   8.43                          8.36
# 7                                   8.41                          8.34
# 8                                   8.37                          8.31
# 9                                   8.34                          8.29
#
# name  Mushoku Tensei: Isekai Ittara Honki Dasu Part 2  Ousama Ranking  \
# week
# 2                                                8.62            8.23
# 3                                                8.61            8.55
# 4                                                8.62            8.72
# 5                                                8.62            8.78
# 6                                                8.66            8.81
# 7                                                8.66            8.83
# 8                                                8.66            8.84
# 9                                                8.68            8.85
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei suru  \
# week
# 2                                                   NaN
# 3                                                  7.68
# 4                                                  7.70
# 5                                                  7.71
# 6                                                  7.71
# 7                                                  7.71
# 8                                                   NaN
# 9                                                   NaN
#
# name  Senpai ga Uzai Kouhai no Hanashi  Takt Op. Destiny  \
# week
# 2                                 7.77              8.15
# 3                                 7.81              8.10
# 4                                 7.84              8.00
# 5                                 7.85              7.93
# 6                                 7.86              7.86
# 7                                 7.86              7.81
# 8                                 7.86              7.78
# 9                                 7.86              7.76
#
# name  World Trigger 3rd Season
# week
# 2                         8.06
# 3                         8.08
# 4                         8.12
# 5                         8.14
# 6                         8.17
# 7                         8.16
# 8                         8.16
# 9                         8.15

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(mal.columns)))))
for col in list(mal.columns):
    c = next(color)
    plt.plot(mal[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#plt.ylim(7.5, 9.0)
plt.show()

# %%
anidb = anidb.pivot(index='week', columns='name', values='score')
anidb
# Out:
# name  86 (2021)  Blue Period  Heike Monogatari  Isekai Shokudou 2  \
# week
# 2          7.45          NaN              7.18               6.81
# 3          7.63          NaN              7.25                NaN
# 4          7.71          NaN              7.17                NaN
# 5          7.57          NaN              7.17                NaN
# 6          7.59          NaN              7.19               6.81
# 7          7.66         6.84              7.26                NaN
# 8          7.72         6.85              7.37                NaN
# 9          7.77         6.90              7.32                NaN
#
# name  Kimetsu no Yaiba: Mugen Ressha Hen  Kimetsu no Yaiba: Yuukaku Hen  \
# week
# 2                                    NaN                            NaN
# 3                                   7.19                            NaN
# 4                                   7.33                            NaN
# 5                                   7.29                            NaN
# 6                                   7.40                            NaN
# 7                                   7.48                            NaN
# 8                                   7.50                            NaN
# 9                                   7.58                           7.84
#
# name  Komi-san wa, Komyushou Desu.  Lupin Sansei: Part 6  \
# week
# 2                             7.02                  6.96
# 3                             7.14                  7.13
# 4                             6.86                  7.13
# 5                             6.93                  7.20
# 6                             7.03                  7.23
# 7                             7.07                  7.23
# 8                             7.13                  7.13
# 9                             7.17                  7.13
#
# name  Mushoku Tensei: Isekai Ittara Honki Dasu (2021)  Ousama Ranking  \
# week
# 2                                                7.19            7.21
# 3                                                7.33            7.60
# 4                                                7.84            7.52
# 5                                                7.78            7.52
# 6                                                7.82            7.72
# 7                                                7.87            7.72
# 8                                                7.96            7.76
# 9                                                8.00            7.81
#
# name  Saihate no Paladin  \
# week
# 2                   7.00
# 3                   6.86
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
#
# name  Sekai Saikou no Ansatsusha, Isekai Kizoku ni Tensei Suru  \
# week
# 2                                                  6.91
# 3                                                   NaN
# 4                                                  6.80
# 5                                                  6.73
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
#
# name  Senpai ga Uzai Kouhai no Hanashi  World Trigger 3rd Season
# week
# 2                                 7.12                       NaN
# 3                                 7.02                      7.10
# 4                                 7.00                      7.10
# 5                                 6.75                      7.08
# 6                                 6.79                      7.28
# 7                                 6.82                      7.28
# 8                                 6.93                      7.40
# 9                                  NaN                      7.52

# %%
plt.figure(figsize=(10,7))
color = iter(cm.rainbow(np.linspace(0, 1, len(list(anidb.columns)))))
for col in list(anidb.columns):
    c = next(color)
    plt.plot(anidb[col], label=col, color=c)
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#plt.ylim(6.5, 8.0)
plt.show()
